# %% [markdown]
# ### Prerequisites

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
from dotenv import load_dotenv
import matplotlib.pyplot as plt

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Data Loading

# %%
data_dir = Path(os.environ['dataset_dir'])
df = pd.read_csv(data_dir / 'train.csv')
df = df.set_index('row_id')

# %%
data = df.sample(frac=0.01)

# %%
# I just took two most important features in catboost
plt.scatter(data.f_231, data.f_225, c=data.target, alpha=0.3)
plt.colorbar()

# %%
# two random features
plt.scatter(data.f_15, data.f_284, c=data.target, alpha=0.3)
plt.colorbar()
